# %% [markdown]
# # Aicraft Spotter Project
#
# See : https://www.robots.ox.ac.uk/~vgg/data/fgvc-aircraft/

# %% [markdown]
# ## Extraction of dataset

# %%
# !wget https://www.robots.ox.ac.uk/~vgg/data/fgvc-aircraft/archives/fgvc-aircraft-2013b.tar.gz
# !tar -xf fgvc-aircraft-2013b.tar.gz
# Out:
# --2020-12-13 14:12:29--  https://www.robots.ox.ac.uk/~vgg/data/fgvc-aircraft/archives/fgvc-aircraft-2013b.tar.gz
# Resolving www.robots.ox.ac.uk (www.robots.ox.ac.uk)... 129.67.94.2
# Connecting to www.robots.ox.ac.uk (www.robots.ox.ac.uk)|129.67.94.2|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2753340328 (2.6G) [application/x-gzip]
# Saving to: ‘fgvc-aircraft-2013b.tar.gz’
#
# fgvc-aircraft-2013b 100%[===================>]   2.56G  11.9MB/s    in 3m 46s
#
# 2020-12-13 14:16:17 (11.6 MB/s) - ‘fgvc-aircraft-2013b.tar.gz’ saved [2753340328/2753340328]

# %% [markdown]
# ## Imports

# %%
import matplotlib.pyplot as plt
import random as rd
import matplotlib.image as mpimg

# %%
# !pwd
# Out:
# /content

# %% [markdown]
# ## Visualisation

# %%
# get image names
train_names=[]
with open("fgvc-aircraft-2013b/data/images_train.txt","r") as f:
  for name in f.readlines():
    train_names.append(name[:-1])

# print n images
n=10
plt.figure(figsize=(10,10))
for i in range(n):
  img=train_names[rd.randint(0,len(test_names))]+".jpg"
  plt.subplot(5,5,i+1)
  img=mpimg.imread('fgvc-aircraft-2013b/data/images/'+img)
  plt.imshow(img)
plt.show()
